# %%
airthmetic operastor

# %%
a=15
b=20
print(a+b)
# Out:
# 35

# %%
a=50
b=18
print(a-b)
# Out:
# 32

# %%
a=9
b=7
print(a*b)
# Out:
# 63

# %%
a=5000
b=2
print(a%b)
# Out:
# 0

# %%
a=12
print(a**12)
# Out:
# 8916100448256

# %%
b=5
print(b**5)
# Out:
# 3125

# %%
a=29
b=5
print(a//b)
# Out:
# 5

# %%
comparioson operators

# %%
a=10
b=5
print(a>b)
# Out:
# True

# %%
a=15
b=20
print(a<b)
# Out:
# True

# %%
a=20
b=20
print(a==b)
# Out:
# True

# %%
a=30
b=10
print(a!=b)
# Out:
# True

# %%
a=45
b=40
print(a>=b)
# Out:
# True

# %%
a=8
b=3
print(a<=b)
# Out:
# False

# %%
logical operator

# %%
a=10
b=5
print(a or b)
# Out:
# 10

# %%
a=15
n=18
print(a and n)
# Out:
# 18

# %%
assignment operator

# %%
x=10
x+=5
print(x)
# Out:
# 15

# %%
x=20
x-=4
print(x)
# Out:
# 16

# %%
x=6
x**=3
print(x)
# Out:
# 216

# %%
x=6
x*=3
print(x)
# Out:
# 18

# %%
x=40
x/=2
print(x)
# Out:
# 20.0

# %%
x=5
x*=2
print(x)
# Out:
# 10

# %%
x=20
x//=3
print(x)
# Out:
# 6

# %%
membership operator

# %%
h="apple"
print("a"  in "h")
# Out:
# False

# %%
b="python"
print("x"not in "b")
# Out:
# True
